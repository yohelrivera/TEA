# %%
# Importando librerias

# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
# datos

# %%
data = pd.read_csv("data.csv")

# %%
data
# Out:
#     Day  # of Units Produced  Time (Hours)  Throughput  Unnamed: 4  \
# 0     1                700.0            24        29.2         NaN
# 1     2                900.0            24        37.5         NaN
# 2     3                  1.0            24        41.7         NaN
# 3     4                600.0            24        25.0         NaN
# 4     5                800.0            24        33.3         NaN
# 5     6                  1.2            24        50.0         NaN
# 6     7                  1.1            24        45.8         NaN
# 7     8                900.0            24        37.5         NaN
# 8     9                  1.2            24        50.0         NaN
# 9    10                700.0            24        29.2         NaN
# 10   11                800.0            24        33.3         NaN
# 11   12                900.0            24        37.5         NaN
# 12   13                  1.0            24        41.7         NaN
# ...

# %%
# grafico

# %%
fig, ax = plt.subplots()
ax.barh(data.Day, data.Throughput)
ax.set(xlabel="Rendimiento %", ylabel="Dia",title="Producción")
# Out:
# [Text(0.5, 0, 'Rendimiento %'),
#  Text(0, 0.5, 'Dia'),
#  Text(0.5, 1.0, 'Producción')]
